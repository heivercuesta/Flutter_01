# %% [markdown]
# #**Componentes Widget Básicos en Flutter**
#
# /
#
# ### En Flutter, un widget es una descripción de una parte de la interfaz de usuario. Estos son los bloques de construcción esenciales que usarás en el 90% de tus aplicaciones.
